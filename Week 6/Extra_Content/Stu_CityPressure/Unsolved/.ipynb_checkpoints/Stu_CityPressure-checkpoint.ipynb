# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint

#import api_key
from config import api_key

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
api_key = '25bc90a1196e6f153eece0bc0b0fc9eb'

# %%
# Build partial query URL
query_url = url + "appid=" + api_key + "&q=" + "London"
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=London'

# %%
test = requests.get(query_url).json()
pprint(test)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1526608200,
#  'id': 2643743,
#  'main': {'humidity': 81,
#           'pressure': 1026,
#           'temp': 279.14,
#           'temp_max': 281.15,
#           'temp_min': 277.15},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 5091,
#          'message': 0.005,
#          'sunrise': 1526616267,
#          'sunset': 1526673023,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 1.5}}

# %%
# list of cities to query
cities = ["London", "Paris", "Las Vegas", "Stockholm", "Sydney", "Hong Kong"]

for city in cities:
    city_weather = weather.main
    print (city_weather)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2f58fd834267> in <module>()
#       3
#       4 for city in cities:
# ----> 5     city_weather = weather.main
#       6     print (city_weather)
#
# NameError: name 'weather' is not defined

# %%
# list for response results
for city in cities:
    print(f'{query_url}&q={city})'
          


# loop through cities, make API request, and append desired results
# Out:
#   File "<ipython-input-11-1d4ee275c495>", line 9
#     # loop through cities, make API request, and append desired results
#                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
# build a dataframe from the cities, lon,and pressure lists

# %%
# Build a scatter plot for each data type


# Incorporate the other graph properties


# Save the figure


# Show plot
