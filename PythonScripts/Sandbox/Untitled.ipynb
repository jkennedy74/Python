# %%
import numpy as np
import pandas as pd
import json
import requests
from pprint import pprint

# %%
url = 'https://data.cityofchicago.org/resource/6zsd-86xi.json?year=2018'

#https://data.cityofchicago.org/resource/6zsd-86xi.json?year=2001

# %%
crime = requests.get(url).json()

pprint(crime)
# Out:
# [{'arrest': True,
#   'beat': '2533',
#   'block': '046XX W NORTH AVE',
#   'case_number': 'JB259222',
#   'community_area': '25',
#   'date': '2018-05-11T09:45:00.000',
#   'description': 'RETAIL THEFT',
#   'district': '025',
#   'domestic': False,
#   'fbi_code': '06',
#   'id': '11311946',
#   'iucr': '0860',
#   'latitude': '41.909664252',
#   'location': {'coordinates': [-87.742728815, 41.909664252], 'type': 'Point'},
#   'location_description': 'DEPARTMENT STORE',
#   'longitude': '-87.742728815',
#   'primary_type': 'THEFT',
#   'updated_on': '2018-05-18T15:52:39.000',
#   'ward': '37',
#   'x_coordinate': '1145011',
#   'y_coordinate': '1910225',
#   'year': '2018'},
#  {'arrest': False,
#   'beat': '1223',
#   'block': '023XX W WASHINGTON BLVD',
#   'case_number': 'JB259788',
#   'community_area': '28',
#   'date': '2018-05-11T16:55:00.000',
#   'description': 'SIMPLE',
#   'district': '012',
#   'domestic': False,
#   'fbi_code': '08A',
#   'id': '11312278',
# ...

# %%
print(type(crime))
# Out:
# <class 'list'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7a6a29eaf8c3> in <module>()
# ----> 1 crime.index(['id'])
#
# ValueError: ['id'] is not in list

# %%
crime_df = pd.DataFrame(crime)
crime_df.head()
# Out:
#    arrest  beat                    block case_number community_area  \
# 0    True  2533        046XX W NORTH AVE    JB259222             25
# 1   False  1223  023XX W WASHINGTON BLVD    JB259788             28
# 2   False  0612          015XX W 78TH ST    JB267454             71
# 3   False  2213      099XX S BEVERLY AVE    JB260091             73
# 4   False  1924       008XX W ALDINE AVE    JB260236              6
#
#                       date                     description district  domestic  \
# 0  2018-05-11T09:45:00.000                    RETAIL THEFT      025     False
# 1  2018-05-11T16:55:00.000                          SIMPLE      012     False
# 2  2018-05-04T19:00:00.000  SEXUAL EXPLOITATION OF A CHILD      006     False
# 3  2018-05-11T20:45:00.000                  UNLAWFUL ENTRY      022     False
# 4  2018-05-11T21:00:00.000                      AUTOMOBILE      019     False
#
#   fbi_code  ...       latitude  \
# 0       06  ...   41.909664252
# ...
