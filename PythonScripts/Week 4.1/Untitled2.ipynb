# %%
import pandas as pd

# %%
df = pd.read_csv("Resources/ufoSightings.csv")
# Out:
# C:\Users\julia\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2 = df.dropna(axis = 0, how = "any")

# %%
df.count()
# Out:
# datetime                80332
# city                    80332
# state                   74535
# country                 70662
# shape                   78400
# duration (seconds)      80332
# duration (hours/min)    80332
# comments                80317
# date posted             80332
# latitude                80332
# longitude               80332
# dtype: int64

# %%
df2.count()
# Out:
# datetime                66516
# city                    66516
# state                   66516
# country                 66516
# shape                   66516
# duration (seconds)      66516
# duration (hours/min)    66516
# comments                66516
# date posted             66516
# latitude                66516
# longitude               66516
# dtype: int64

# %%
group_df = df2.groupby(["country", "state"]).count()
group_df
# Out:
#                datetime  city  shape  duration (seconds)  \
# country state
# au      al            1     1      1                   1
#         dc            1     1      1                   1
#         nt            2     2      2                   2
#         oh            1     1      1                   1
#         sa            2     2      2                   2
#         wa            2     2      2                   2
#         yt            1     1      1                   1
# ca      ab          284   284    284                 284
#         bc          677   677    677                 677
#         mb          124   124    124                 124
#         nb           86    86     86                  86
#         nf           15    15     15                  15
#         ns          101   101    101                 101
#         nt           13    13     13                  13
#         on         1335  1335   1335                1335
# ...

# %%
print(type(group_df))
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
